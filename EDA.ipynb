# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/manch/Downloads/data.csv")

# %%
data.head()
# Out:
#      datetime     open     high      low    close       volume       reserve  \
# 0  2020-07-16  9190.80  9216.02  9005.00  9130.11  8765.698589  2.889262e+06
# 1  2020-07-17  9130.93  9182.99  9054.99  9154.29  6423.747162  2.889943e+06
# 2  2020-07-18  9154.29  9210.00  9122.65  9175.85  4121.626974  2.890642e+06
# 3  2020-07-19  9175.83  9245.03  9105.37  9212.87  3520.072476  2.892067e+06
# 4  2020-07-20  9214.01  9223.51  9131.00  9161.05  5815.330842  2.891858e+06
#
#    funding_rates      mvrv          nrpl      nupl  stock_to_flow_reversion  \
# 0       0.009332  1.563972 -3.694023e+06  0.360602                 0.421011
# 1       0.007262  1.568555  3.367513e+05  0.362471                 0.366354
# 2       0.004125  1.572507  7.637219e+06  0.364073                 0.404649
# 3       0.007809  1.579355  2.053120e+07  0.366830                 0.409607
# 4       0.010244  1.568483  7.103351e+06  0.362441                 0.437860
#
# ...

# %%
data.tail()
# Out:
#        datetime      open      high       low     close        volume  \
# 930  2023-02-01  23127.15  23813.57  22760.00  23735.97  20292.224170
# 931  2023-02-02  23735.97  24262.18  23367.87  23493.84  16368.921383
# 932  2023-02-03  23497.29  23720.00  23208.01  23433.54  14215.668430
# 933  2023-02-04  23433.47  23589.67  23257.71  23328.87   3567.130075
# 934  2023-02-05  23329.47  23433.20  22758.01  22936.34   6536.140584
#
#           reserve  funding_rates      mvrv          nrpl      nupl  \
# 930  2.228658e+06       0.010046  1.197895  3.665064e+08  0.165202
# 931  2.225632e+06       0.017552  1.185242  1.677386e+08  0.156290
# 932  2.221115e+06       0.012482  1.181964  1.003611e+08  0.153951
# 933  2.219863e+06       0.007240  1.176299  1.410151e+08  0.149876
# 934  2.222216e+06       0.003896  1.156946  3.282193e+06  0.135655
#
#      stock_to_flow_reversion  sth_sopr signal        RSI         9_ema  \
# ...

# %%
data.shape
# Out:
# (935, 20)

# %%
data.describe()
# Out:
#                open          high           low         close         volume  \
# count    935.000000    935.000000    935.000000    935.000000     935.000000
# mean   32854.990235  33748.030417  31841.441326  32869.649166   19776.787469
# std    15586.619424  16026.828089  15051.951866  15570.876889   12739.460780
# min     9130.930000   9182.990000   9005.000000   9130.110000    3211.704593
# 25%    19239.850000  19554.870000  18850.245000  19258.600000   11166.544857
# 50%    33077.430000  34231.540000  31432.190000  33080.660000   16961.108288
# 75%    45709.475000  47058.655000  44145.240000  45705.135000   24086.969086
# max    67554.130000  69000.000000  66261.790000  67554.840000  119633.961941
#
#             reserve  funding_rates        mvrv          nrpl        nupl  \
# count  9.350000e+02     935.000000  935.000000  9.350000e+02  935.000000
# mean   2.655477e+06       0.010833    1.887077  2.638039e+08    0.364061
# ...

# %%
data.columns
# Out:
# Index(['datetime', 'open', 'high', 'low', 'close', 'volume', 'reserve',
#        'funding_rates', 'mvrv', 'nrpl', 'nupl', 'stock_to_flow_reversion',
#        'sth_sopr', 'signal', 'RSI', '9_ema', '21_ema', '50_ema', '200_ema',
#        'Fear_and_Greed_Index'],
#       dtype='object')

# %%
data.nunique()
# Out:
# datetime                   935
# open                       935
# high                       930
# low                        928
# close                      935
# volume                     935
# reserve                    935
# funding_rates              935
# mvrv                       935
# nrpl                       935
# nupl                       935
# stock_to_flow_reversion    935
# sth_sopr                   935
# signal                       3
# RSI                        935
# 9_ema                      935
# 21_ema                     935
# 50_ema                     935
# 200_ema                    935
# Fear_and_Greed_Index        84
# dtype: int64

# %%
data.isnull().sum()
# Out:
# datetime                   0
# open                       0
# high                       0
# low                        0
# close                      0
# volume                     0
# reserve                    0
# funding_rates              0
# mvrv                       0
# nrpl                       0
# nupl                       0
# stock_to_flow_reversion    0
# sth_sopr                   0
# signal                     0
# RSI                        0
# 9_ema                      0
# 21_ema                     0
# 50_ema                     0
# 200_ema                    0
# Fear_and_Greed_Index       0
# dtype: int64

# %%
corelation=data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 corelation=data.corr()
#
# File c:\Users\manch\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\manch\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...
